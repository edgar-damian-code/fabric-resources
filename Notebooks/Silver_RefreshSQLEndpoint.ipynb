# %% [markdown]
# # Refresh SQL Endpoint
# ###### This notebook refreshes the SQL endpoint for the connected lakehouse. Useful for reading from the lakehouse directly after a write operation.

# %%
import json 
import notebookutils 
import sempy.fabric as fabric 
from sempy.fabric.exceptions import FabricHTTPException, WorkspaceNotFoundException 

def pad_or_truncate_string(input_string, length, pad_char=' '):
    # Truncate if the string is longer than the specified length
    if len(input_string) > length:
        return input_string[:length]
    # Pad if the string is shorter than the specified length
    return input_string.ljust(length, pad_char)

def display_return(data):
    table_details = [
        {
        'tableName': table['tableName'],
        'status':  table['status'],
        'startDateTime':  table['startDateTime'],
        'endDateTime':  table['endDateTime'],
        'lastSuccessfulSyncDateTime':  table['lastSuccessfulSyncDateTime'],
        'error':  table['error']
        }
        for table in data
        ]
    for detail in table_details:
        print(f"Table: {pad_or_truncate_string(detail['tableName'],20)} status: {detail['status']} start: {detail['startDateTime']}  end: {detail['endDateTime']}  Last Update: {detail['lastSuccessfulSyncDateTime']}  error: {detail['error']}  ")
    print('')
    #print(data)
    
    return;


workspace_id=spark.conf.get("trident.workspace.id")
lakehouse_id=spark.conf.get("trident.lakehouse.id")

#Instantiate the client
client = fabric.FabricRestClient()

# This is the SQL endpoint I want to sync with the lakehouse, this needs to be the GUI
sqlendpoint = fabric.FabricRestClient().get(f"/v1/workspaces/{workspace_id}/lakehouses/{lakehouse_id}").json()['properties']['sqlEndpointProperties']['id']

# URI for the call 
uri = f"v1/workspaces/{workspace_id}/sqlEndpoints/{sqlendpoint}/refreshMetadata?preview=true" 

# This is the action, we want to take 
payload = {} 

try:
    response = client.post(uri,json= payload, lro_wait = True) 
    sync_status = json.loads(response.text)
    display_return(sync_status)

except Exception as e: print(e)
# Out:
# StatementMeta(, 686fe1af-d683-43b8-8e70-91f462714243, 3, Finished, Available, Finished)
# Table: util_etl_silver_to_g status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-03-17T20:54:56.0024505Z  error: None
# Table: etl_silver_to_gold_c status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-03-17T20:54:56.2680625Z  error: None
# Table: etl_bronze_to_silver status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-05-05T09:35:18.1806097Z  error: None
# Table: bix_fact_concession  status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.2691456Z  error: None
# Table: bix_fact_floorplanst status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-02T21:40:25.4946608Z  error: None
# Table: bix_fact_lease       status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.987929Z  error: None
# Table: bix_fact_amenityassi status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T11:24:43.4062203Z  error: None
# Table: bix_fact_operational status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-02T21:40:22.0727466Z  error: None
# Table: bix_fact_propertymar status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:12.253611Z  error: None
# Table: bix_fact_operational status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.9723137Z  error: None
# Table: bix_fact_marketingtr status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-02T21:40:22.7446409Z  error: None
# Table: bix_fact_unitmarketr status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-02T21:40:20.9164926Z  error: None
# Table: bix_dim_guest        status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.0035137Z  error: None
# Table: bix_dim_residentmemb status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.409767Z  error: None
# Table: bix_dim_concession   status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.5347688Z  error: None
# Table: bix_dim_leaseattribu status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.706643Z  error: None
# Table: bix_dim_concessionfl status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:08.8473683Z  error: None
# Table: bix_dim_unitvacancyh status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:09.1129869Z  error: None
# Table: bix_dim_marketingcha status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:09.2536858Z  error: None
# Table: bix_dim_concessionle status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:09.3785688Z  error: None
# Table: bix_fact_rentrolllea status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:09.5035738Z  error: None
# Table: bix_dim_concessionun status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:09.6129813Z  error: None
# Table: bix_dim_concessionca status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:09.9879708Z  error: None
# Table: bix_dim_residentmemb status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:10.1129067Z  error: None
# Table: bix_dim_employee     status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:10.2379065Z  error: None
# Table: bix_dim_amenityprope status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:10.4879526Z  error: None
# Table: bix_dim_amenity      status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:10.6597997Z  error: None
# Table: bix_dim_resident     status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:10.7847859Z  error: None
# Table: bix_fact_propertypro status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T11:24:42.6093212Z  error: None
# Table: bix_dim_floorplan    status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.0816768Z  error: None
# Table: bix_fact_propertysta status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-02T21:40:25.135285Z  error: None
# Table: bix_dim_unit         status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.2223316Z  error: None
# Table: bix_dim_floorplangro status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.4254791Z  error: None
# Table: bix_dim_concessionqu status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.6129622Z  error: None
# Table: bix_dim_unitavailabi status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.7535842Z  error: None
# Table: bix_dim_property     status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:11.878592Z  error: None
# Table: bix_fact_resident    status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:12.1442228Z  error: None
# Table: bix_fact_demographic status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:07.8941471Z  error: None
# Table: hd_building_availabi status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:53:02.4702651Z  error: None
# Table: hd_concessions_histo status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:47:57.7861534Z  error: None
# Table: hd_building_availabi status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:47:58.0361555Z  error: None
# Table: hd_building_availabi status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:47:58.2236584Z  error: None
# Table: hd_building_availabi status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:47:58.3642912Z  error: None
# Table: hd_amenity           status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:53:02.6109002Z  error: None
# Table: hd_subject_compariso status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:47:58.5205399Z  error: None
# Table: hd_property          status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-07T19:47:58.6299146Z  error: None
# Table: bix_dim_renewal      status: NotRun start: 2025-06-10T14:24:00.7379262Z  end: 2025-06-10T14:24:02.8628585Z  Last Update: 2025-06-10T11:23:10.925448Z  error: None
